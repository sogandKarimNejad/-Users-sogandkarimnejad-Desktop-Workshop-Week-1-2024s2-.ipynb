# %% [markdown]
# # COMP2200/COMP6200 Week 1 Practical

# %% [markdown]
# The goal of this week's practical is to get you started using Python, Jupyter Notebooks, and Git, three tools that you will use through the semester in your work.
#
# **Python** is our language of choice in COMP2200/COMP6200. If you do not have any experience of using Python, you need to learn basic Python coding.
#
# You are looking at a **Jupyter Notebook**, it is a document that mixes text, code and the output of the code. A lot of your work will be creating notebooks like this to present your analysis.
#
# **Git** is a distributed version control system (DVCS), you will use it to keep track of your work and ensure that you have a backup copy of what you are doing. You should have checked this notebook out of **Github** using Git. Your task this week is to complete some programming work in this worksheet and commit your changes to your own Bitbucket repository.

# %% [markdown]
# ## Python Basics

# %% [markdown]
# Your task this week is to complete some basic programming tasks with Python in this worksheet.  There are questions below with a space for you to write code to achieve the given outcomes. Write the code, test it, and when you are done, submit your work as described at the end of the notebook.
#
# The tasks aren't meant to be complicated Python problems, just some simple tasks to get you started with this process.

# %% [markdown]
# ### Examples - basics
# - How to define a variable
# - How to perform some basic arithmatic operation
# - How to use a constant

# %%
# Let's show an example of calculating the area of a circle

# Define the radius
radius = 5

# Then we can calculate the area. 
# We need to make use of a constant PI (around 3.1415926), which is defined in the module math
import math

area = math.pi * radius * radius

print("The area of the circle is: ", area)
# Out:
# The area of the circle is:  78.53981633974483

# %% [markdown]
# - How to use a built-in function
#
# To calculate the the squared radius "raius*radius", we could also use the built-in function pow() in the math module.

# %%
# Task 1: Re-calculate the area of the circle above with using the funciton pow(). 
# Read the manual about how to call the function and write your code below and print the result.

# write your code here: 
radius = 6
import math 
area = math.pi * radius * radius 
print("the area of the circle is: ", area)
# Out:
# the area of the circle is:  113.09733552923255

# %% [markdown]
# ### Examples - control structures
# - Braching strucutre: if-else
# - Loop structure: for, while
# - Boolean values: True/False

# %%
# Let's test if a given number is even or odd, we need to use the if-else structure

# The built-in input() function can let you input a string. 
# Let's input an integer number and test if it's even or odd.

x = input()

# Now x is a string. We need to convert it to an integer.
x = int(x)

# Now can divid x by 2 to check its parity.
if x%2 == 0:
    print("It's an even number.")
else:
    print("It's an odd number.")

y = input()
y = int(y)
if y%5 == 0 :
    print("its an even number.")
else: 
    print ("its an odd number.")

# %%
# Now we go further to check if the given number is a prime number of not.
# To be a prime number, it cannot be divided by the number less than it. So, simply use the loop structure to test.


x = input()

# Now x is a string. We need to convert it to an integer.
x = int(x)

# Now we use a loop to try to divide the number by the numbers less than it.
# 0 and 1 are not prime.
if x < 2:
    print("It's not a prime number.")
else:
    # 2 is a prime number
    if x == 2:
        print("It's a prime nubmer.")
    else:
        
        # Use a loop to test its factor
        # We use the built-in function range(a, b) to generate all the integer numbers between a (included) and b (excluded)
        is_prime = True
        for i in range(2, x):
            # To test if i is a factor for x
            if x%i == 0:
                is_prime = False
                break
        if is_prime:
            print("It's a prime nubmer.")
        else:
            print("It's not a prime number.")

# %%
x = input()
x = int(x) 
if x < 2 : 
    print ("it's not a prime number.")
else: 
    if x == 2 : 
        print("it's a prime number.")
    is_prime = True 
for i in range ( 2, x) :
    if x%i == 0: 
        is_prime = False
    break 
if is_prime:
    print ("it's a prime number")
else: 
    print("it's not a prime number")
# Out:
#  17
# it's a prime number

# %% [markdown]
# ### Example - defining a function
# - How to define your own function
#
# Python is a dynamically typed language so we don't need to declare the type of a variable or declare the return type of a function (although Python 3 introduced optional [type hints](https://docs.python.org/3/library/typing.html)).  Apart from that the idea of writing a function in Python is the same as in Processing or (methods in) Java.
#
# Write a function that takes a single string argument and returns the number of words in the string using the code you wrote above to count words.

# %%
# Now, to make things easier for the number primality test, we can make a self-defined function. 
# We can just simply resue the code above

def is_prime(x):
    # Now we use a loop to try to divide the number by the numbers less than it.
    # 0 and 1 are not prime.
    if x < 2:
        return False
    else:
        # 2 is a prime number
        if x == 2:
            return True
        else:
            # Use a loop to test its factor
            # We use the built-in function range(a, b) to generate all the integer numbers between a (included) and b (excluded)
            for i in range(2, x):
                # To test if i is a factor for x
                if x%i == 0:
                    return False
            return True

# Now, let's try to call this function to test a number

x = input()

# Now x is a string. We need to convert it to an integer.
x = int(x)

# Now we can directly call the function we defined before.
if is_prime(x):
    print("It's a prime nubmer.")
else:
    print("It's not a prime number.")

def  is_prime(x)

x == input()
x == int(x)

if is_prime(x): 
    print ("it's a prime number.")
else: 
    print ("it's not a prime number.")

# %%
# Task 2: Now we want to have a smarter way to perform the primality test. 
# We can improve the testing process with less computation by an optimisation strategy.
# Strategy: You just need to test the factors less than the sqared root of number, i.e., sqrt(x). 
# The reason is that one of the factors (if any) of the number x must not be greater than sqrt(x).
# Your task is to define a new version of the primality testing function is_prime_faster(x).
# write your code here: 
import math 
def is_prime_faster(x):
    if x < 2:
        return False
    if x == 2:
        return True
    if x % 2 == 0:
        return False
    for i in range(3, int(math.sqrt(x)) + 1, 2):
        if x % i == 0:
            return False
    return True
x = input()
x = int(x)
if is_prime_faster(x):
    print("it's a prime number.")
else: 
    print("it's a prime number.")
def is_prime_faster(x):
    x == input()
    x == int(x)
# Out:
#  17
# it's a prime number.

# %% [markdown]
# ## String Manipulation
#
# The next cell defines three strings that you will use for the following group of questions. Note that the first uses single quotes, the second uses double quotes and the third uses three double quotes since it includes newline characters.  These are all valid ways of writing strings in Python and are equivalent.

# %%
#### title = 'Data Science'

code = "COMP2200/COMP6200"

description = """This unit introduces students to the fundamental techniques and 
tools of data science, such as the graphical display of data, 
predictive models, evaluation methodologies, regression, 
classification and clustering. The unit provides practical 
experience applying these methods using industry-standard 
software tools to real-world data sets. Students who have 
completed this unit will be able to identify which data 
science methods are most appropriate for a real-world data 
set, apply these methods to the data set, and interpret the 
results of the analysis they have performed. """

# %% [markdown]
# Task 3.
#
# Write code to print the length of these strings, i.e., how many words they contain.

# %%
title = 'Data Science'

code = "COMP2200/COMP6200"

description = """This unit introduces students to the fundamental techniques and 
tools of data science, such as the graphical display of data, 
predictive models, evaluation methodologies, regression, 
classification and clustering. The unit provides practical 
experience applying these methods using industry-standard 
software tools to real-world data sets. Students who have 
completed this unit will be able to identify which data 
science methods are most appropriate for a real-world data 
set, apply these methods to the data set, and interpret the 
results of the analysis they have performed. """

print (len(title))
print(len(code))
print(len(description))
# Out:
# 12
# 17
# 587

# %% [markdown]
# Write code to create a new string in a variable 'summary' that contains the code, title and the first 20 characters of the description, with a ':' character between each one (ie 'COMP2200/COMP6200:Data Science:This unit...'

# %%
# write your code here: create a new string summary and then print it
summary = code + ":" + title + ":" + description [:21]
print (summary)
# Out:
# COMP2200/COMP6200:Data Science:This unit introduces

# %% [markdown]
# Write code to find the number of words in the description.  Hint, this is easy in Python since strings support the [split method](https://docs.python.org/3.6/library/stdtypes.html#str.split) that returns a list of strings after splitting on whitespace (or another character if you wish).   Try split on the string, then find out how many strings are in the resulting list.

# %%
#write your code here

# %% [markdown]
# ## Data generation and plotting
#
# Just to give you a taste of some of the capabilities of Jupyter notebooks and Python we will look at a very simple example of data handling and plotting.  First you need to import some libraries that will allow you to do this: `matplotlib` does the plotting. You also need to use the random module to generate random numbers.
#
# - How to use an array
# - the random module
# - Gaussian distribution
# - Pyhton plotting

# %%
import random

# %% [markdown]
# The Gaussian or Normal disbribution is often used in data science for data distribution modelling and data analytics. The Python random module has the function gauss() that draws a random number from a Gaussian distribition. Two parameter $\mu$ and $\sigma$ should be given to determine a Gaussian distribution.

# %%
# Random draw a number from a Gauassian distribution
mu=0
sigma=5
x = random.gauss(mu, sigma)
print(x)

# Use a loop to draw a set of 100 such random numbers
# x is an array for the generated numbers
x=[]
for i in range(100):
    x.append(random.gauss(mu, sigma))

print(x)
# Out:
# 1.4774785157818007
# [3.9382744715212734, 1.1459855794223535, -0.33466904691661964, -2.65926180162888, 2.9631745411120263, -0.6456969367532899, 8.930807213758179, 2.525706465297843, 0.7767386869308457, -1.2996036625176148, 0.44124018300775386, -1.0314096126588825, 2.9223712485567717, -5.893255572542497, 7.115349409818994, -0.9243668316855825, 2.989435913751122, 1.4702238712360973, -3.5410235744254823, 4.990670636212493, -0.35527490911262527, -5.197406580139417, 2.528153548718955, 5.877725800821714, -1.4889979723238103, -4.693442395992448, -0.3835970018426413, -4.556982506163179, 2.5221635701088205, 2.370544587654644, -8.665829138964614, -5.077888020374325, -1.5889672074182757, 0.818891844821283, -4.563944028398502, -1.9591897227796526, -7.238939266325599, 0.5434877603264603, -5.240810535759312, -0.01734238315914804, 5.34450968543907, 0.8874032233128535, 7.440994476983899, -1.3050866622182293, 9.055267121297113, -2.033934302376644, -1.4912126361437519, -3.8221673084011822, -1.7139296107884805, 4.3375800592689835, 2.3722379688401922, -1.1983636435397202, -4.976112082641999, 3.425614235276147, 0.8735326177399017, 2.4016845949890575, -6.2198807760159855, 3.0259717916059605, 1.3147490083959141, -13.551461001810143, -4.715367945858329, -5.5810910864922665, 4.092506047321316, -2.7192234513793383, -0.9967688792618644, 5.668792238977426, 0.8461921009117521, -9.134174694593437, 8.293181364798722, -6.541375554535309, -0.08194373969300434, 0.13817092050570395, -2.2186526104123403, 2.1582572697639253, 3.8797184534180107, -2.6599351002761358, -0.5251508773351957, -6.901929948305811, 1.6201446417100887, -2.3528160189229195, 0.22157926862140384, 5.96686394951154, 3.757020067943821, 5.8874719339263315, 3.0484317887211203, 1.876336109032903, -6.403254243341153, -4.076765876590345, 3.7412336776189505, -8.018584627352721, 4.1465510547247595, 6.88035724961242, -8.639422608166328, 2.330458731837612, 0.7379419471803018, -1.869918519348919, 2.579403717564668, -2.9734648767330354, 3.450209943326322, 0.3938897876272362]

# %% [markdown]
# In terms of the probability density function, we can calculate the probability density for the genrated random number. The probability density function is defined as $p(x)=\frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}$.

# %%
# We can implement the probabiity density function as follows:
def pdf(mu, sigma, x):
    return math.exp(-0.5*math.pow(x-mu, 2)/pow(sigma, 2))/math.sqrt(2*math.pi*pow(sigma, 2))


# The probability density example
mu=0
sigma=5
print(pdf(mu, sigma, 0))


# Now we can calculate the probablity density for the random numbers generated above. 
# You need to ensure that the distribution is the same, i.e., the same mu and sigma.
y=[]
for i in x:
    y.append(pdf(mu, sigma, i))

print(y)
# Out:
# 0.07978845608028654
# [0.05850889050191842, 0.07772004273584945, 0.07960992459532215, 0.06926539056160268, 0.06693826429094868, 0.07912590695148575, 0.01618674153784448, 0.07023136248894538, 0.07883147717105986, 0.0771382633644682, 0.07947837526083304, 0.0781087992975795, 0.0672605416297029, 0.039835943528841414, 0.02898605606091475, 0.07843652920286388, 0.06672931033428986, 0.07641260494174981, 0.062091051122672755, 0.048484442115589006, 0.07958729170222176, 0.046484463112972295, 0.0702139933070419, 0.039981850816117735, 0.07632774740527708, 0.0513574907900012, 0.07955398916365398, 0.05267057982712904, 0.07025648744037069, 0.07130662215824762, 0.017768850280207072, 0.047640340813350605, 0.07585946605046656, 0.07872550299814564, 0.052603735348708616, 0.07389242696768734, 0.027975636301810654, 0.07931848903020355, 0.04606516073709386, 0.07978797614099577, 0.04506487678254191, 0.07854165678567616, 0.02636430092101426, 0.0771162334835523, 0.01547802971367457, 0.07345265569120983, 0.07631767255630403, 0.0595728286315238, 0.07523584195340964, 0.05476694496730626, 0.07129516932533704, 0.07752940819013271, 0.048625350209424524, 0.06309756476670764, 0.07858003414521292, 0.07109500317217872, 0.036805249924304125, 0.06643664107293751, 0.07707720132962893, 0.002026959582432166, 0.051146033146484096, 0.0427944011179218, 0.05707731306719348, 0.06882006258517061, 0.07821863116531705, 0.041958235234819924, 0.07865396267606886, 0.015040038619681088, 0.02016284774368332, 0.033905829133115524, 0.07977774156680117, 0.07975799674303259, 0.07230768706011077, 0.0726909828479196, 0.05904704669661706, 0.06926042938669831, 0.07934958083406775, 0.030773258831961196, 0.07570782019109804, 0.07142614429827192, 0.07971014646390187, 0.039146441546799506, 0.06016404035391825, 0.03989026534799151, 0.06625560770802802, 0.07436356390804058, 0.03514019160091845, 0.05722428854053885, 0.060306641868017236, 0.022052475095513443, 0.05657126214732264, 0.030956794783501277, 0.017931991876810528, 0.071575874962714, 0.07892418175334058, 0.07439932937066569, 0.06984736508953386, 0.06685652904571739, 0.06288450942242581, 0.07954125755864823]

# %% [markdown]
# Now we will create a simple plot.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()

# Settings
ax.set_xlabel('x')
ax.set_ylabel('probability density')
ax.set_title('Random Numbers from Gaussian Distribution')

# Plot the random numbers (X-axis) and their probability density (Y-axis)
ax.scatter(x, y)

plt.show()

# %%
# Task 4. In this task, please change the values mu and sigma to define another Gaussian distribution.
# Then, generate 1000 random numbers, calculate their probaiblity density values, and plot as we did in the example above.

# Your code here:
import random 
mu = 2
sigma = 10
x = random. gauss (mu, sigma)
print (x)
x = []
for i in range(1000):
    x.append (random.gauss(mu, sigma))
print (x)
# Out:
# -4.402042708108516
# [-8.544958006542364, -0.41849498847308064, 10.435994361927603, -3.84659476647452, 17.46343714105675, -1.5409657357064255, 8.706827065705605, 5.406736597844794, -15.199916865382864, 4.69673855501204, 10.063872937782724, 13.302689854796101, -14.076834655838827, 1.2029871665722633, -14.05636912893793, 1.8398249350234215, -15.085359932261113, 8.324041421817494, 4.0422229647101755, 8.271345506586439, -6.0922213987772285, -0.611570550362015, 6.451749481782193, -4.749244679985525, 1.8405749675802707, -8.047901636401491, 13.450175437873751, -2.4297569082695247, -13.049755317836587, -8.512457581802126, -0.7334198229920794, 12.969424024464622, 0.5799822655852742, 10.758614982937548, -9.213787474317192, 3.628053639631445, -19.07220470827373, 2.682298142905167, 0.4481153526240802, -4.728946829448575, 15.634705132890875, -14.084726659090943, -6.675266743468944, 8.603848088689963, -1.5655138443403143, 2.2491022951251236, 14.417449804986735, 21.822098755165825, 15.95948689075925, 1.875772081438011, 14.053859751508414, 14.646444832409623, -17.396982824629553, 0.40367189438422857, -6.693907094636268, -6.530638354415251, 13.255787069971152, -1.9912872556272787, -5.884561571161108, -6.931623720336409, 13.042677694014497, -10.782901178413798, 6.539838863009976, -9.088481674701573, 1.5282479879209758, 18.689818302007055, -10.093706081120615, -9.063257386831896, -0.3147373653621801, 1.1949665401584204, 2.388651334212404, 2.444123950227827, 7.124789650340425, 6.377953496020054, 6.481754389742569, 11.903008446442538, -3.3396983687326145, 8.51430406932705, 14.843640858929001, -4.4174064728541484, 3.702554552239185, 5.740235293247626, 16.04415610672762, 0.42490545300746163, 3.255472980304485, 9.295977889812084, 11.621892903279752, 0.13732660179469547, 5.6553990623000345, -5.812654269063369, -12.319501500980444, -6.207922274942833, 5.668881348911158, 14.684610340763012, -5.836842943340979, -5.258001631155007, 8.917992939353212, 6.90366023753926, 7.0077239833535785, 0.9234203248903601, -11.8552824509642, -4.26351539755857, 2.241029028198664, -4.270770190938132, -0.01578489335054023, -5.002462693111897, 0.8584029476272592, 20.081811718992466, -14.116626008859516, 3.1766029365266015, 3.7629907226181647, -2.0499753648701677, -0.9092954527164587, -1.5870420381611412, -8.9324749213677, 5.9244436151666235, 10.144933145113752, 15.358885119319819, 2.944189056053271, -4.215675408735784, -4.93944550016469, 7.6336665014541065, -2.4711257268035194, 20.326895985715176, -12.735561903349854, 13.63335724559178, -0.13458739540284181, -1.6602356351296934, -17.446481458674985, -5.478459460318971, 12.260586230419229, -8.429640444383024, 9.931328086789708, 2.7662868686351993, 2.506597663021802, -15.01960527340265, -2.3711093884295646, 6.265077552991515, 6.834281271118029, 17.608741809516893, 1.1478451859472247, 15.151434769179227, -6.27707827413176, 6.096354154362846, -1.7821919935241288, 3.757449267805821, 10.240422790393064, -7.039944659776705, 2.5307106619479547, -4.580471069818284, 2.049997474230497, 0.8217715701036792, -8.02048100666875, 6.5753001903987, -4.356152782334403, 6.825995288086356, 7.195925300609797, 11.533333220622984, -5.748413067543681, -9.504430215516928, -0.4034835127862255, 2.533207024746157, -3.1629009167754525, 7.505335602797434, -0.8190301150194914, -0.9680309477898295, -19.547303709462252, 13.138746732807892, 2.434802423346145, 9.17346936715891, 11.158359852366468, 1.2802978903394897, -8.484062873702351, 11.98846554667286, -17.652632954047693, 15.457818910045107, -14.939478527374835, 5.570773985588296, 1.0699067203403823, 8.561488389011604, -5.004993529238304, 18.069471867037702, 10.299142369499444, -7.981134619767699, 5.3446428807376165, -1.5772812622520385, 2.043338275385491, -16.122897727081256, 2.5811366923505314, 2.5074017582017145, 9.375188692632465, 3.2724874643389636, -11.326130314524402, 0.23888847526575963, 4.712559251528463, 6.688526504396372, -5.615902533028699, -9.10371926409072, -26.827221314778242, 16.869730898821707, -4.8243159330638 ...
# 0.039104269397545584

# %%
import math 
def pdf (mu, sigma, x):
    return math.exp(-0.5*math.pow(x-mu, 2)/pow(sigma, 2))/math.sqrt(2*math.pi*pow(sigma, 2))
mu = 2
sigma = 10 
print(pdf(mu, sigma, 0))
y = []
for i in x:
    y.append(pdf(mu, sigma, i))
    print (y)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...
# [0.022879720624850466, 0.03874439354945351, 0.027949565347617483, 0.03362662960936157, 0.01206902450094683, 0.037469956844723776, 0.031859130292974554, 0.0376450842588596, 0.009088827862935666, 0.038469651534500514, 0.028820917309908125, 0.02106215152176218, 0.010956233788488317, 0.03976771910798799, 0.010992318434936726, 0.0398891107265416, 0.009269079100270191, 0.032663692935078356, 0.0390709130972179, 0.032772271621653595, 0.028754992862537177, 0.03855671017583168, 0.036130640965655686, 0.03176833801976414, 0.03988915853575929, 0.024081165400720753, 0.020711706358607602, 0.03616594468374107, 0.012855297422271584, 0.02295814626804587, 0.03843135770066013, 0.02185851035498852, 0.03949402524923471, 0.027184989672117188, 0.02127401777141734, 0.03936900609958032, 0.004332057474358249, 0.03980147607858719, 0.03941671334728822, 0.03181182339683388, 0.015747879676251877, 0.010942338098289194, 0.02738321918933803, 0.032078229935150575, 0.037437287806230485, 0.039881852386172624, 0.018453726981183662, 0.005593771001464225, 0.015057787233304728, 0.039891149805426386, 0.01929322461846665, 0.017931677083349792, 0.006080074439783373, 0.03938914755828741, 0.027338926068622475, 0.027726058169157217, 0.021173871390352688, 0.03683983685853437, 0.029235978667028362, 0.02677214928474642, 0.021682988207311443, 0.017623246248176478, 0.03598783512920348, 0.021573366544433998, 0.03984986043529065, 0.009909376974629413, 0.01920062861573701, 0.021633722687189237, 0.038839649043628195, 0.03976516423046504, 0.03986410932742464, 0.03985490253422655, 0.03498482191925966, 0.03624854594799903, 0.03608224949717348, 0.024431756239623566, 0.034593636862338524, 0.03226718808829826, 0.0174866214540225, 0.03246998498196324, 0.03932019256968796, 0.03719911060550576, 0.01488032765566907, 0.039402412233236775, 0.039581054844314276, 0.030571713497667997, 0.025111540907437245, 0.0392081209268435, 0.037315990751655356, 0.029401444892601027, 0.014310464267321191, 0.028485116204610687, 0.03729757089316412, 0.017845206973869078, 0.029345849320567163, 0.03065631614487124, 0.03140410199730219, 0.035374889566281556, 0.03519292806996136, 0.03966370484169162, 0.015277595271039172, 0.03278835845071563, 0.03988264144865126, 0.03277345401335744, 0.03909187751031705, 0.031220009954623873, 0.03963511364735699, 0.007779344480053576, 0.010886282203876173, 0.039619034835346616, 0.03927903717482208, 0.03675301086135839, 0.03824113056105966, 0.037408475629885876, 0.021947135135360122, 0.03693742868018316, 0.028632200414045465, 0.01634517251341725, 0.03971679666107531, 0.03288637863703399, 0.03135745800035537, 0.03404014834086372, 0.03609942100108111, 0.0074398900493847855, 0.01347111454480021, 0.020278407474995663, 0.03899562015247278, 0.03730938965170919, 0.006021903751811165, 0.030162362529715468, 0.023566671841663507, 0.023158100982943717, 0.029128055803731883, 0.039777271246553246, 0.039843068360140024, 0.009373596317107971, 0.03625940030185727, 0.03642579655195683, 0.03549458947610107, 0.0117996226058209, 0.03974964116038327, 0.01680086663244861, 0.028323207709872854, 0.036683646855723, 0.03714045368567846, 0.03928286870950318, 0.02840908004497895, 0.026512827050500114, 0.03983808577516307, 0.0321277022137135, 0.0398937294157894, 0.03961827658126948, 0.0241475144809476, 0.03592971947750078, 0.03259726084951545, 0.03550879812136908, 0.034856633176168966, 0.025325440435248134, 0.02954877026111371, 0.020583135590713356, 0.038758418654479335, 0.03983755674392887, 0.034916305395111105, 0.03428431813127057, 0.03834012503533981, 0.03817518183343736, 0.003914940639660381, 0.021453187996913602, 0.0398565352109599, 0.03084387961625308, 0.026228690709176647, 0.03979104142581232, 0.023026685467356593, 0.02422498243981828, 0.00578403619519576, 0.01612977920711046, 0.009501997017529086, 0.03743026188314174, 0.039722043490151196, 0.03216780164605754, 0.031214476608322567, 0.01096920742494651, 0.028271460486613, 0.024242721094965246, 0.03772407454659968, 0.03742155766952525, 0.03989385339398746, ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
fig.ax = plt. subplots ()
ax.set_xlabel('x')
ax.set_ylabel('probability density')
ax.set_title ('random numbers from gaussian distribution')
ax.scatter(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 import numpy as np
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/__init__.py:964
#     957     return config
#     960 # When constructing the global instances, we need to perform certain updates
#     961 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     962 # triggering resolution of _auto_backend_sentinel.
#     963 rcParamsDefault = _rc_params_in_file(
# --> 964     cbook._get_data_path("matplotlibrc"),
#     965     # Strip leading comment.
#     966     transform=lambda line: line[1:] if line.startswith("#") else line,
#     967     fail_on_error=True)
#     968 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
#     969 # Normally, the default matplotlibrc file contains *no* entry for backend (the
#     970 # corresponding line starts with ##, not #; we fill on _auto_backend_sentinel
#     971 # in that case.  However, packagers can set a different default backend
#     972 # (resulting in a normal `#backend: foo` line) in which case we should *not*
#     973 # fill in _auto_backend_sentinel.
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/cbook.py:545, in _get_data_path(*args)
#     539 def _get_data_path(*args):
#     540     """
#     541     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     542
#     543     ``*args`` specify a path relative to the base data path.
#     544     """
# --> 545     return Path(matplotlib.get_data_path(), *args)
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %% [markdown]
# ## Checkpoint
#
# You got your copy of this notebook by forking and then cloning my Github repository.  Now that you have made some changes you should commit your work with a suitable commit message and push your changes back to your Github repository.  Show your tutor your updated Github repository to get your checkpoint mark.
